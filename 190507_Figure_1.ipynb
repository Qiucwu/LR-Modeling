# %% [markdown]
# # How to think about treating heterogeneous initial populations

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
from scipy.integrate import solve_ivp
import sys
import pickle
from pyDOE import *
from scipy.stats.distributions import norm

# %%
u_N = .02
u_SCM = .005
u_TM = 0.32
u_CM = 0.35
u_EM = 0.30
u_EMRA = 0.005
std = 0.1
u_T = [u_N, u_SCM, u_TM, u_CM, u_EM,u_EMRA]

# %%
# Set plotting parameters
font = {'family' : 'Arial',
        'weight' : 'normal',
        'size'   : 15}

plt.rc('font', **font)

# %%
sims = 10000
design = lhs(6, samples=sims)
means = u_T
stdvs = [std] * 6
for i in range(6):
    design[:, i] = norm(loc=means[i], scale=stdvs[i]).ppf(design[:, i])

# %%
#pick my initial population
sim = 10000
x = abs(design)
y = np.sum(x, axis = 1)

for i in range(sim):
    x[i] = x[i]/y[i]

# %% [markdown]
# Something weird is happening with the proliferation rates. Don't know if my calculations are correct. Probably a good idea to look at other sources

# %%
d = 1
LRA = 1
p_cm = 0.00075 * d
p_tm = 0.0006 * d
p_em = 0.0003 * d
p_n = 0.000099 * d
p_scm = 0.00001 * d
p_emra = 0.00005 * d


corr_fact = -np.log(1/2)
d_n = corr_fact * (1/1500)
d_scm = corr_fact * (1/150)
d_tm = corr_fact * (1/100)
d_cm = corr_fact * (1/120)
d_em = corr_fact * (1/90)
d_emra = corr_fact * (1/250)
n = 0.00017
a = n
w = 1/20 # In Ke's 2015 paper, it looks like a reasonable assumption is 20-50 days because thats where copies of vRNA start dropping

d_ALL = 0.003

# %% [markdown]
# ## Define Model

# %%
#Define the model
def model(z,t):
    L_n = z[0]
    L_scm = z[2]
    L_tm = z[4]
    L_cm = z[6] 
    L_em = z[8]
    L_emra = z[10]
    
    A_n = z[1]
    A_scm = z[3]
    A_tm = z[5]
    A_cm = z[7]
    A_em = z[9]
    A_emra = z[11]
    
    
    #for drug dosings
    dL_ndt = (p_n - d_n)*L_n - a*L_n + w*A_n
    dA_ndt = a*L_n - d_ALL*A_n - w*A_n
    
    dL_scmdt = (p_scm - d_scm)*L_scm - a*L_scm + w*A_scm
    dA_scmdt = a*L_scm - d_ALL*A_scm - w*A_scm
    
    dL_tmdt = (p_tm - d_tm)*L_tm - a*L_tm + w*A_tm
    dA_tmdt = a*L_tm - d_ALL*A_tm - w*A_tm
    
    dL_cmdt = (p_cm - d_cm)*L_cm - a*L_cm + w*A_cm
    dA_cmdt = a*L_cm - d_ALL*A_cm - w*A_cm
    
    dL_emdt = (p_em - d_em)*L_em - a*L_em + w*A_em
    dA_emdt = a*L_em - d_ALL*A_em - w*A_em
    
    dL_emradt = (p_emra - d_emra)*L_emra - a*L_emra + w*A_emra
    dA_emradt = a*L_emra - d_ALL*A_emra - w*A_emra
    
    
    dzdt = [dL_ndt,dA_ndt,
            dL_scmdt,dA_scmdt,
            dL_tmdt,dA_tmdt,
            dL_cmdt,dA_cmdt,
            dL_emdt,dA_emdt,
            dL_emradt,dA_emradt
            ]
    return dzdt

# %% [markdown]
# ## Set initial conditions and solve for idealize intial conditions without the variablity

# %%
#initial conditions, there are three
z0 = np.zeros(12)
ctr=0
for i in range(6):
    z0[ctr] = u_T[i]*10**6
    ctr+=2

b = 2000
tn = 60001
t = np.linspace(0,tn-1, b)


#store solutions
#Drug Doses
L_n = np.empty_like(t)
L_scm = np.empty_like(t)
L_tm = np.empty_like(t)
L_cm = np.empty_like(t)
L_em = np.empty_like(t)
L_emra = np.empty_like(t)

A_n = np.empty_like(t)
A_scm = np.empty_like(t)
A_tm = np.empty_like(t)
A_cm = np.empty_like(t)
A_em = np.empty_like(t)
A_emra = np.empty_like(t)
Total = np.empty_like(t)


#record intial

L_n[0] = z0[0]
L_scm[0] = z0[2]
L_tm[0] = z0[4]
L_cm[0] = z0[6] 
L_em[0] = z0[8]
L_emra[0] =z0[10]

A_n[0] = z0[1]
A_scm[0] = z0[3]
A_tm[0] = z0[5]
A_cm[0] = z0[7]
A_em[0] = z0[9]
A_emra[0] = z0[11]

Total[0] = np.sum(z0)

#Solve the ODE
for i in range(1,b):
    tspan = [t[i-1],t[i]]
    # solve for next step
    z = odeint(model,z0,tspan)
    # store solution for plotting
        
    L_n[i] = z[1][0]
    L_scm[i] = z[1][2]
    L_tm[i] = z[1][4]
    L_cm[i] = z[1][6] 
    L_em[i] = z[1][8]
    L_emra[i] = z[1][10]
    
    A_n[i] = z[1][1]
    A_scm[i] = z[1][3]
    A_tm[i] = z[1][5]
    A_cm[i] = z[1][7]
    A_em[i] = z[1][9]
    A_emra[i] = z[1][11]
    
    
    Total[i]=np.sum(z[1])
    z0 = z[1] 
    
t = t/365

# %%
fig, ax = plt.subplots(figsize = (15,4), sharey = True)
ax = plt.subplot(121)
plt.title('Dynamics of All T Cells', y= 1.05)
plt.plot(t,L_n,'g--',label='L_n')
plt.plot(t,A_n,'g-',label='A_n')
plt.plot(t,L_scm,'r--',label='L_scm')
plt.plot(t,A_scm,'r-',label='A_scm')
plt.plot(t,L_tm,'k--',label='L_tm')
plt.plot(t,A_tm,'k-',label='A_tm')
plt.plot(t,L_cm,'y--',label='L_cm')
plt.plot(t,A_cm,'y-',label='A_cm')
plt.plot(t,L_em,'b--',label='L_em')
plt.plot(t,A_em,'b-',label='A_em')
plt.plot(t,L_emra,'c--',label='L_emra')
plt.plot(t,A_emra,'c-',label='A_emra')
plt.plot(t,Total,'orange', label = 'Total', linewidth = 4, linestyle = ':')
plt.xlabel('Years')
plt.ylabel('Reservoir Size (Cell #)')
plt.yscale('log')
#plt.xscale('symlog')
plt.ylim([0.5,10**6])
plt.xlim([0,10])

box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.75, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left',ncol=2, bbox_to_anchor=(1, 0.5))

# %%
def HIV_decay(L0,t):
    L_t = L0 * np.exp((-5*10**-4)*t) 
    return L_t
t = np.linspace(0,tn-1, b)
L_t = []
for tmp in t:
    L_t.append(HIV_decay(10**6, tmp))

# %%
def HIV_years(L0, d):
    t = np.log((1-10**-16)/10**6)/(-d)
    return t

# %%
sims = 100000
design = lhs(1, samples=sims)
means = 5.2*10**-4
stdvs = 1.6*10**-4
design[:] = norm(loc=means, scale=stdvs).ppf(design[:])

# %%
plt.figure(figsize = (10,4))
d = np.random.normal(5.2*10**-4, scale = 1.6*10**-4, size = 100000)
L0 = 10**6
plt.subplot(121)
a = HIV_years(L0,d)/365
a = a[abs(a)< 200]
#plt.vlines(np.mean(HIV_years(L0,d))/365, 0,0.025, label = 'Mean = {:.2f}'.format(np.mean(HIV_years(L0,d))/365))
plt.hist(a, bins = 40, density = True) 
plt.xlabel('Years')
plt.ylabel('Probability Density')
plt.title('Siciliano Years to Cure' , y = 1.05)
plt.xlim([1,150])
plt.ylim([0,0.025])

plt.subplot(122)
#plt.vlines(np.mean(tot_arr)/365, 0, 0.025, label = 'Mean = {:.2f}'.format(np.mean(tot_arr)/365))
plt.hist(tot_arr[tot_arr!=0]/365, bins = 25, density = True, label = 'Model Estimate')
plt.xlabel('Years')
plt.ylabel('Probability Density')
plt.title('Model Years to Cure' , y = 1.05)
plt.xlim([1,150])
plt.ylim([0,0.025])

plt.tight_layout()

# %%
plt.figure(figsize = (10,4))
d = np.random.normal(5.2*10**-4, scale = 1.6*10**-4, size = 100000)
L0 = 10**6
plt.subplot(121)
a = HIV_years(L0,d)/365
a = a[abs(a)< 200]

plt.hist(a, bins = 50, density = True, label = 'Clinical Estimate') 

plt.hist(tot_arr[tot_arr!=0]/365, bins = 60, density = True, label = 'Model Estimate', alpha = 0.5)
plt.xlabel('Years')
plt.ylabel('Probability Density')
plt.title('Siliciano Years to Cure Model Validation' , y = 1.05)
plt.xlim([1,150])
plt.ylim([0,0.025])
plt.legend(fontsize = 12)

plt.tight_layout()

# %%
np.std(tot_arr[tot_arr!=0])/365
# Out:
# 21.74262277435982

# %%
y = np.mean(pop_dict, axis = 0)
y_err = np.std(pop_dict, axis =0)
#plt.errorbar(np.linspace(0,2000,2000), y , y_err, linewidth = 1)
plt.scatter(np.linspace(0,2000,2000),y, s = 1)
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-6dd6c9d56582> in <module>
# ----> 1 y = np.mean(pop_dict, axis = 0)
#       2 y_err = np.std(pop_dict, axis =0)
#       3 #plt.errorbar(np.linspace(0,2000,2000), y , y_err, linewidth = 1)
#       4 plt.scatter(np.linspace(0,2000,2000),y, s = 1)
#       5 plt.yscale('log')
#
# ~/anaconda3/envs/scanpy_env/lib/python3.7/site-packages/numpy/core/fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2918
#    2919     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2920                           out=out, **kwargs)
#    2921
#    2922
#
# ~/anaconda3/envs/scanpy_env/lib/python3.7/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims)
#      60
#      61     is_float16_result = False
# ---> 62     rcount = _count_reduce_items(arr, axis)
#      63     # Make this warning show up first
#      64     if rcount == 0:
#
# ~/anaconda3/envs/scanpy_env/lib/python3.7/site-packages/numpy/core/_methods.py in _count_reduce_items(arr, axis)
#      53     items = 1
#      54     for ax in axis:
# ---> 55         items *= arr.shape[ax]
#      56     return items
#      57
#
# IndexError: tuple index out of range

# %%
np.mean(tot_arr[tot_arr!=0]/365)
# Out:
# 72.38930628611553

# %%
f = plt.figure(figsize = (10, 4))
ax = plt.subplot(121)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])


plt.vlines(np.mean(tot_arr[tot_arr!=0])/365, 0, 0.025, label = 'Model Mean = {:.2f}'.format(np.mean(tot_arr[tot_arr!=0])/365))
plt.vlines(HIV_years(10**6, 5*10**-4)/365, 0, 0.025, label = 'Siciliano Mean = {:.2f}'.format(HIV_years(10**6, 5.2*10**-4)/365), color = 'red')
plt.hist(tot_arr/365, bins = 200, density = True, label = 'Model Estimate')
plt.xlabel('Years')
plt.ylabel('Probability Density')
plt.title('Years to Cure' , y = 1.05)
plt.xlim([1,150])
plt.ylim([0,0.025])
# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
pop_dict = pickle.load(open('190507_pop_LHS.p','rb'))

# %%
b = 2000
tn = 60001
t = np.linspace(0,tn-1, b)

# %%
sims = 10000
tot_arr = np.zeros([sims])
for i in range(10000):
    a = np.where(pop_dict['total'][i] < 1)[0]
    if len(a)== 0:
        tot_arr[i] = 0
    else:
        tot_arr[i] = t[a[0]]

# %%
plt.plot(t/365, L_t, label = 'Estimated Decay from Siliciano et al.', c = 'red')
plt.plot(t/365, Total, label = 'Estimated Decay from Model')
plt.ylim([1,10**6])
plt.xlim([0,80])
plt.xlabel('Years')
plt.ylabel('Reservoir Size (Cell #)')
plt.title('Reservoir Decay Over Time', y= 1.05)
plt.yscale('log')
plt.legend()
plt.legend(loc='upper right', fontsize = 12)


print('Siciliano Cure Years: {:.3f}'.format(t[np.where(np.array(L_t)<1)[0][0]]/365))
print('Model Cure Years: {:.3f}'.format(t[np.where(np.array(Total)<1)[0][0]]/365))
# Out:
# Siciliano Cure Years: 75.736
# Model Cure Years: 73.023

# %%
w_tmp = (lhs(1, samples=1000)*3).flatten()
parameter_arr = w_tmp
parameter_letter = 'w'


#number of time points
tn = 2000

#store solutions
L_n = np.zeros([w_tmp.shape[0],tn])
L_scm = np.zeros([w_tmp.shape[0],tn])
L_tm = np.zeros([w_tmp.shape[0],tn])
L_cm = np.zeros([w_tmp.shape[0],tn])
L_em = np.zeros([w_tmp.shape[0],tn])
L_emra = np.zeros([w_tmp.shape[0],tn])

A_n = np.zeros([w_tmp.shape[0],tn])
A_scm = np.zeros([w_tmp.shape[0],tn])
A_tm = np.zeros([w_tmp.shape[0],tn])
A_cm = np.zeros([w_tmp.shape[0],tn])
A_em = np.zeros([w_tmp.shape[0],tn])
A_emra = np.zeros([w_tmp.shape[0],tn])
Total = np.zeros([w_tmp.shape[0],tn])




for i,parameter in enumerate(parameter_arr):
#initial conditions, there are three
    w = 1/20 # In Ke's 2015 paper, it looks like a reasonable assumption is 20-50 days because thats where copies of vRNA start dropping
    d = 1
    LRA = 1
    d_ALL = 0.003

    if parameter_letter == 'w':
        w = parameter
    elif parameter_letter == 'd_ALL':
        d_ALL = parameter
    elif parameter_letter == 'd':
        d = parameter
    elif parameter_letter == 'LRA':
        LRA = parameter
    else: 
        break
    #set parameters

    p_cm = 0.00075 * d
    p_tm = 0.0006 * d
    p_em = 0.0003 * d
    p_n = 0.000099 * d
    p_scm = 0.00001 * d
    p_emra = 0.00005 * d


    corr_fact = -np.log(1/2)
    d_n = corr_fact * (1/1500)
    d_scm = corr_fact * (1/150)
    d_tm = corr_fact * (1/100)
    d_cm = corr_fact * (1/120)
    d_em = corr_fact * (1/90)
    d_emra = corr_fact * (1/250)
    n = 0.00017
    a = n * LRA

    
    z0 = np.zeros(12)
    ctr=0
    for g in range(6):
        z0[ctr] = u_T[g]*10**6
        ctr+=2

    #time points
    b = 2000
    tn = 30001
    t = np.linspace(0,tn-1, b)


    #record intial

    L_n[i][0] = z0[0]
    L_scm[i][0] = z0[2]
    L_tm[i][0] = z0[4]
    L_cm[i][0] = z0[6] 
    L_em[i][0] = z0[8]
    L_emra[i][0] =z0[10]

    A_n[i][0] = z0[1]
    A_scm[i][0] = z0[3]
    A_tm[i][0] = z0[5]
    A_cm[i][0] = z0[7]
    A_em[i][0] = z0[9]
    A_emra[i][0] = z0[11]

    Total[i][0] = np.sum(z0)

    #Solve the ODE
    for k in range(1,b):
        tspan = [t[k-1],t[k]]
        # solve for next step
        z = odeint(model,z0,tspan)
        # store solution for plotting

        L_n[i][k] = z[1][0]
        L_scm[i][k] = z[1][2]
        L_tm[i][k] = z[1][4]
        L_cm[i][k] = z[1][6] 
        L_em[i][k] = z[1][8]
        L_emra[i][k] = z[1][10]

        A_n[i][k] = z[1][1]
        A_scm[i][k] = z[1][3]
        A_tm[i][k] = z[1][5]
        A_cm[i][k] = z[1][7]
        A_em[i][k] = z[1][9]
        A_emra[i][k] = z[1][11]


        Total[i][k] =np.sum(z[1])
        z0 = z[1] 
    sys.stdout.write('\r {}'.format(i) )

t = t/365
pop_dict = {}
pop_dict['latent'] = [L_n, L_scm, L_tm, L_cm, L_em, L_emra]
pop_dict['active'] = [A_n, A_scm, A_tm, A_cm, A_em, A_emra]
pop_dict['times'] = t
pop_dict['total'] = Total
pop_dict['cell_type'] = ['T_n', 'T_scm', 'T_tm', 'T_cm','T_em', 'T_emra']
# Out:
#  999

# %%
pop_dict['w'] = w_tmp

# %%
pickle.dump(pop_dict,open('190430_w_sensitivity.p', 'wb'))

# %%
y = pop_dict['total'][np.argsort(w_tmp)]
x  = sorted(w_tmp)

# %%
hill_cure = []
for i in range(1000):
    hill_cure.append(t[np.where(y[i] <10**2)[0][0]])
y = hill_cure

# %%
from matplotlib.gridspec import GridSpec
fig = plt.figure(figsize = (7,5))

gs = GridSpec(4,4)

ax_joint = fig.add_subplot(gs[1:4,0:3])
plt.grid(True)
plt.xticks(np.arange(0, 1, .2))
plt.yticks(np.arange(34,41,1))
plt.xlim([-.1,1])
ax_joint.set_xlabel(r'$\omega$ range')
ax_joint.set_ylabel('Years to Hill Cure')
plt.title(r'Sensitivity Analysis for $\omega$')
ax_marg_y = fig.add_subplot(gs[1:4,3])

ax_joint.scatter(x,y, s = 10)


ax_marg_y.hist(y,orientation="horizontal", log = True,bins = 20)

plt.setp(ax_marg_y.get_yticklabels(), visible=False)
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]
